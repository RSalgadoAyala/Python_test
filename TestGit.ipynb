# %% [markdown]
# <a href="https://colab.research.google.com/github/RSalgadoAyala/Python_test/blob/main/TestGit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **Importando datos de GitHub**
#
# [Link a repository](https://github.com/RSalgadoAyala/Python_test/tree/main)
#
# Es importante copiar el enlace del archivo desde Raw, de otra forma no se importa el enlace

# %%
# creando data frame para leer los datos
df_doors=pd.read_csv('https://raw.githubusercontent.com/RSalgadoAyala/Python_test/main/LDP_DoorsV01.csv?raw=true',index_col=0)

# %%
# leyendo los primeros 5 datos del archivo
df_doors.head()
# Out:
#       Sample  ...  Omega inner depth Izq Sup
# Mold          ...
# 1          1  ...                       9.38
# 1          2  ...                       9.36
# 1          3  ...                       9.34
# 2          4  ...                       9.76
# 2          5  ...                       9.70
#
# [5 rows x 44 columns]

# %%
# obteniendo los estadìstica descriptiva del arechivo
df_doors.describe()
# Out:
#           Sample  ...  Omega inner depth Izq Sup
# count  18.000000  ...                  18.000000
# mean    9.500000  ...                   9.487222
# std     5.338539  ...                   0.133584
# min     1.000000  ...                   9.310000
# 25%     5.250000  ...                   9.365000
# 50%     9.500000  ...                   9.465000
# 75%    13.750000  ...                   9.562500
# max    18.000000  ...                   9.760000
#
# [8 rows x 44 columns]

# %%
# valores promedio agrupados por molde
df_doors.groupby('Mold').mean()
# Out:
#       Sample  ...  Omega inner depth Izq Sup
# Mold          ...
# 1          2  ...                   9.360000
# 2          5  ...                   9.716667
# 3          8  ...                   9.340000
# 4         11  ...                   9.563333
# 5         14  ...                   9.493333
# 6         17  ...                   9.450000
#
# [6 rows x 44 columns]

# %%
# creating a DataFrame for Flange data and displaying data
df_doorsFl=df_doors[['Sample','Flange Angle IZQ SUP (jaladera)','Flange Angle IZQ INF','Flange Angle DER SUP (bisagra)','Flange Angle DER INF']]
df_doorsFl.head()
# Out:
#       Sample  ...  Flange Angle DER INF
# Mold          ...
# 1          1  ...                 89.78
# 1          2  ...                 89.88
# 1          3  ...                 89.62
# 2          4  ...                 91.45
# 2          5  ...                 91.66
#
# [5 rows x 5 columns]

# %%
# creating a DataFrame with the means of flanges per mould
df_doorsFLM=df_doorsFl.groupby('Mold').mean()
df_doorsFLM.head()
# Out:
#       Sample  ...  Flange Angle DER INF
# Mold          ...
# 1          2  ...             89.760000
# 2          5  ...             91.543333
# 3          8  ...             90.430000
# 4         11  ...             91.680000
# 5         14  ...             90.520000
#
# [5 rows x 5 columns]
