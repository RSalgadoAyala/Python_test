# %% [markdown]
# # Basic chart and stadistical data
#
# * Upload data
# * Data cleaning
# * Histograms with tolerances
# * Scatter charts with tolerances
# * Basic summary of data

# %%
# Basic libraries
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# upload data from local folder
df_ang = pd.read_csv(r'C:\Users\salgar\Rodrigo Jan 2022\Phyton\CronosAngles01.csv')

# %%
df_ang.head()
# Out:
#       Date  Sample  Mold  Ángulo Superior Derecho FC  \
# 0  1/27/22       1     1                       84.75
# 1  1/27/22       2     1                       87.57
# 2  1/27/22       3     1                       86.56
# 3  1/27/22       4     1                       87.52
# 4  1/27/22       5     1                       86.32
#
#    Ángulo Inferior Derecho FC  Ángulo Superior Izquierdo FC  \
# 0                       87.30                         88.87
# 1                       86.84                         90.10
# 2                       87.11                         88.92
# 3                       89.64                         86.00
# 4                       90.42                         88.15
#
#    Ángulo Inferior Izquierdo FC
# 0                         88.74
# 1                         92.90
# 2                         89.42
# 3                         89.63
# 4                         88.03

# %%
df_ang.describe()
# Out:
#           Sample       Mold  Ángulo Superior Derecho FC  \
# count  35.000000  35.000000                   35.000000
# mean    7.285714   1.342857                   88.261429
# std     4.462731   1.055597                    1.817086
# min     1.000000   1.000000                   84.750000
# 25%     3.500000   1.000000                   86.565000
# 50%     7.000000   1.000000                   88.740000
# 75%    11.000000   1.000000                   89.960000
# max    15.000000   5.000000                   90.680000
#
#        Ángulo Inferior Derecho FC  Ángulo Superior Izquierdo FC  \
# count                   35.000000                     35.000000
# mean                    89.463143                     90.253143
# std                      1.491954                      1.832772
# min                     86.840000                     86.000000
# 25%                     88.585000                     89.040000
# 50%                     89.640000                     90.130000
# ...

# %%
df_molds = df_ang.groupby('Mold', axis=0).mean()

# %%
df_molds.head()
# Out:
#         Sample  Ángulo Superior Derecho FC  Ángulo Inferior Derecho FC  \
# Mold
# 1     7.870968                   88.022581                   89.272903
# 2     5.000000                   89.970000                   90.820000
# 4     1.000000                   89.780000                   91.900000
# 5     2.500000                   90.350000                   90.515000
#
#       Ángulo Superior Izquierdo FC  Ángulo Inferior Izquierdo FC
# Mold
# 1                        90.030645                         91.28
# 2                        92.160000                         92.43
# 4                        91.850000                         90.80
# 5                        91.950000                         91.90

# %%
df_molds.describe()
# Out:
#          Sample  Ángulo Superior Derecho FC  Ángulo Inferior Derecho FC  \
# count  4.000000                    4.000000                    4.000000
# mean   4.092742                   89.530645                   90.626976
# std    3.011090                    1.032926                    1.080725
# min    1.000000                   88.022581                   89.272903
# 25%    2.125000                   89.340645                   90.204476
# 50%    3.750000                   89.875000                   90.667500
# 75%    5.717742                   90.065000                   91.090000
# max    7.870968                   90.350000                   91.900000
#
#        Ángulo Superior Izquierdo FC  Ángulo Inferior Izquierdo FC
# count                      4.000000                      4.000000
# mean                      91.497661                     91.602500
# std                        0.986506                      0.712104
# ...

# %%
df_ang.plot(kind='box',figsize=(8,6))
plt.show()

# %%
df_ang.head()
# Out:
#       Date  Sample  Mold  Ángulo Superior Derecho FC  \
# 0  1/27/22       1     1                       84.75
# 1  1/27/22       2     1                       87.57
# 2  1/27/22       3     1                       86.56
# 3  1/27/22       4     1                       87.52
# 4  1/27/22       5     1                       86.32
#
#    Ángulo Inferior Derecho FC  Ángulo Superior Izquierdo FC  \
# 0                       87.30                         88.87
# 1                       86.84                         90.10
# 2                       87.11                         88.92
# 3                       89.64                         86.00
# 4                       90.42                         88.15
#
#    Ángulo Inferior Izquierdo FC
# 0                         88.74
# 1                         92.90
# 2                         89.42
# 3                         89.63
# 4                         88.03

# %%
df_ang.tail()
# Out:
#        Date  Sample  Mold  Ángulo Superior Derecho FC  \
# 30  2/10/22       1     4                       89.78
# 31  2/10/22       2     5                       90.18
# 32  2/10/22       3     5                       90.52
# 33  2/10/22       4     1                       90.00
# 34  2/10/22       5     2                       89.97
#
#     Ángulo Inferior Derecho FC  Ángulo Superior Izquierdo FC  \
# 30                       91.90                         91.85
# 31                       90.44                         92.00
# 32                       90.59                         91.90
# 33                       90.15                         91.50
# 34                       90.82                         92.16
#
#     Ángulo Inferior Izquierdo FC
# 30                         90.80
# 31                         92.71
# 32                         91.09
# 33                         92.00
# 34                         92.43
